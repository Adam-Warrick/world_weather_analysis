# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low= -90.000, high = 90.000, size = 2000)

lngs = np.random.uniform(low = -180.000, high=180.00, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 775

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | najran
# Processing Record 2 of Set 1 | chapais
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | basco
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | devyatka
# City not found. Skipping...
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | talnakh
# Processing Record 17 of Set 1 | titusville
# Processing Record 18 of Set 1 | thurso
# Processing Record 19 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 20 of Set 1 | saposoa
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | takoradi
# Processing Record 23 of Set 1 | hofn
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | la cruz
# Processing Record 26 of Set 1 | vardo
# Processing Record 27 of Set 1 | poddorye
# Processing Record 28 of Set 1 | bardiyah
# Processing Record 29 of Set 1 | kununurra
# Processing Record 30 of Set 1 | davidson
# Processing Record 31 of Set 1 | hun
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | aleksandrov gay
# Processing Record 34 of Set 1 | bambous virieux
# Processing Record 35 of Set 1 | sao miguel do araguaia
# Processing Record 36 of Set 1 | cabo san lucas
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 39 of Set 1 | puerto ayacucho
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | jiuquan
# Processing Record 42 of Set 1 | egvekinot
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | dingle
# Processing Record 45 of Set 1 | fayetteville
# Processing Record 46 of Set 1 | mount gambier
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | luderitz
# Processing Record 49 of Set 1 | aykhal
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | pisco
# Processing Record 2 of Set 2 | lasa
# Processing Record 3 of Set 2 | rybinsk
# Processing Record 4 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 2 | oranjemund
# Processing Record 6 of Set 2 | payo
# Processing Record 7 of Set 2 | klaksvik
# Processing Record 8 of Set 2 | piopio
# Processing Record 9 of Set 2 | kawalu
# Processing Record 10 of Set 2 | hasaki
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | kargapolye
# City not found. Skipping...
# Processing Record 15 of Set 2 | alta floresta
# Processing Record 16 of Set 2 | kaifeng
# Processing Record 17 of Set 2 | asau
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 2 | manyana
# Processing Record 21 of Set 2 | kavaratti
# Processing Record 22 of Set 2 | prince rupert
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | belyy yar
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | provideniya
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | broken hill
# Processing Record 30 of Set 2 | itupiranga
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | puerto escondido
# Processing Record 35 of Set 2 | benguela
# Processing Record 36 of Set 2 | komsomolskiy
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | olesno
# Processing Record 39 of Set 2 | upata
# Processing Record 40 of Set 2 | katsuura
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | mayo
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | opuwo
# Processing Record 45 of Set 2 | chelyabinsk-70
# City not found. Skipping...
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | nouakchott
# Processing Record 48 of Set 2 | la ciotat
# Processing Record 49 of Set 2 | airai
# Processing Record 50 of Set 2 | trinidad
# Processing Record 1 of Set 3 | leningradskiy
# Processing Record 2 of Set 3 | victor harbor
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | moree
# Processing Record 5 of Set 3 | norman wells
# Processing Record 6 of Set 3 | nelson bay
# Processing Record 7 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 3 | tuatapere
# Processing Record 9 of Set 3 | skibbereen
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | exeter
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | vila velha
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | laguna
# Processing Record 16 of Set 3 | millau
# Processing Record 17 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 3 | emerald
# Processing Record 19 of Set 3 | kilmez
# City not found. Skipping...
# Processing Record 20 of Set 3 | duluth
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | chunskiy
# Processing Record 23 of Set 3 | ningbo
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | busselton
# Processing Record 26 of Set 3 | saskylakh
# Processing Record 27 of Set 3 | koumra
# Processing Record 28 of Set 3 | itamaraca
# Processing Record 29 of Set 3 | kuminskiy
# Processing Record 30 of Set 3 | azul
# Processing Record 31 of Set 3 | lavrentiya
# Processing Record 32 of Set 3 | kruisfontein
# Processing Record 33 of Set 3 | sao felix do xingu
# Processing Record 34 of Set 3 | caravelas
# Processing Record 35 of Set 3 | harper
# Processing Record 36 of Set 3 | eyl
# Processing Record 37 of Set 3 | souillac
# Processing Record 38 of Set 3 | san remo
# Processing Record 39 of Set 3 | tanout
# Processing Record 40 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 3 | punta arenas
# Processing Record 42 of Set 3 | simao
# Processing Record 43 of Set 3 | grand baie
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 46 of Set 3 | blackfoot
# Processing Record 47 of Set 3 | mount isa
# Processing Record 48 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 49 of Set 3 | soyo
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | waingapu
# Processing Record 2 of Set 4 | kesennuma
# City not found. Skipping...
# Processing Record 3 of Set 4 | labelle
# Processing Record 4 of Set 4 | smithers
# Processing Record 5 of Set 4 | yellowknife
# Processing Record 6 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 4 | hope
# Processing Record 8 of Set 4 | kaeo
# Processing Record 9 of Set 4 | richards bay
# Processing Record 10 of Set 4 | codrington
# Processing Record 11 of Set 4 | esperance
# Processing Record 12 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 4 | blythe
# Processing Record 14 of Set 4 | burriana
# Processing Record 15 of Set 4 | faanui
# Processing Record 16 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 4 | pilar
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | hualmay
# Processing Record 20 of Set 4 | kinsale
# Processing Record 21 of Set 4 | padang
# Processing Record 22 of Set 4 | huainan
# Processing Record 23 of Set 4 | huaiyin
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | amlagora
# Processing Record 26 of Set 4 | avera
# Processing Record 27 of Set 4 | alice springs
# Processing Record 28 of Set 4 | arlit
# Processing Record 29 of Set 4 | kavieng
# Processing Record 30 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 4 | college
# Processing Record 32 of Set 4 | bluff
# Processing Record 33 of Set 4 | borama
# City not found. Skipping...
# Processing Record 34 of Set 4 | mabaruma
# Processing Record 35 of Set 4 | tadine
# Processing Record 36 of Set 4 | yulara
# Processing Record 37 of Set 4 | port alfred
# Processing Record 38 of Set 4 | qaanaaq
# Processing Record 39 of Set 4 | gaoua
# Processing Record 40 of Set 4 | limoux
# Processing Record 41 of Set 4 | manokwari
# Processing Record 42 of Set 4 | berlevag
# Processing Record 43 of Set 4 | port macquarie
# Processing Record 44 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 4 | naze
# Processing Record 46 of Set 4 | ostrovnoy
# Processing Record 47 of Set 4 | kyzyl-suu
# Processing Record 48 of Set 4 | tiksi
# Processing Record 49 of Set 4 | lompoc
# Processing Record 50 of Set 4 | tuktoyaktuk
# Processing Record 1 of Set 5 | banjar
# Processing Record 2 of Set 5 | sawakin
# Processing Record 3 of Set 5 | mauriti
# Processing Record 4 of Set 5 | teahupoo
# Processing Record 5 of Set 5 | faya
# Processing Record 6 of Set 5 | knysna
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | la tuque
# Processing Record 9 of Set 5 | guerrero negro
# Processing Record 10 of Set 5 | geraldton
# Processing Record 11 of Set 5 | bijapur
# Processing Record 12 of Set 5 | olafsvik
# Processing Record 13 of Set 5 | iquique
# Processing Record 14 of Set 5 | salalah
# Processing Record 15 of Set 5 | trzebiatow
# Processing Record 16 of Set 5 | karratha
# Processing Record 17 of Set 5 | qarchak
# Processing Record 18 of Set 5 | taian
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | honningsvag
# Processing Record 21 of Set 5 | pevek
# Processing Record 22 of Set 5 | arman
# Processing Record 23 of Set 5 | hamilton
# Processing Record 24 of Set 5 | flin flon
# Processing Record 25 of Set 5 | sogdiondon
# City not found. Skipping...
# Processing Record 26 of Set 5 | teya
# Processing Record 27 of Set 5 | opotiki
# Processing Record 28 of Set 5 | pochutla
# Processing Record 29 of Set 5 | tautira
# Processing Record 30 of Set 5 | vanavara
# Processing Record 31 of Set 5 | san patricio
# Processing Record 32 of Set 5 | zabolottya
# City not found. Skipping...
# Processing Record 33 of Set 5 | cockburn town
# Processing Record 34 of Set 5 | ponta delgada
# Processing Record 35 of Set 5 | bonthe
# Processing Record 36 of Set 5 | san cristobal
# Processing Record 37 of Set 5 | wanning
# Processing Record 38 of Set 5 | asyut
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | east london
# Processing Record 41 of Set 5 | bongandanga
# Processing Record 42 of Set 5 | bissau
# Processing Record 43 of Set 5 | ilulissat
# Processing Record 44 of Set 5 | sinnar
# Processing Record 45 of Set 5 | longyearbyen
# Processing Record 46 of Set 5 | ayan
# Processing Record 47 of Set 5 | aklavik
# Processing Record 48 of Set 5 | kosovo polje
# Processing Record 49 of Set 5 | loja
# Processing Record 50 of Set 5 | ouadda
# Processing Record 1 of Set 6 | mongomo
# Processing Record 2 of Set 6 | husavik
# Processing Record 3 of Set 6 | nantucket
# Processing Record 4 of Set 6 | peniche
# Processing Record 5 of Set 6 | vostok
# Processing Record 6 of Set 6 | walvis bay
# Processing Record 7 of Set 6 | cirebon
# Processing Record 8 of Set 6 | zimovniki
# Processing Record 9 of Set 6 | salinopolis
# Processing Record 10 of Set 6 | pumiao
# Processing Record 11 of Set 6 | hobyo
# Processing Record 12 of Set 6 | aginskoye
# Processing Record 13 of Set 6 | dwarka
# Processing Record 14 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 6 | antalaha
# Processing Record 16 of Set 6 | bondo
# Processing Record 17 of Set 6 | motala
# Processing Record 18 of Set 6 | cidreira
# Processing Record 19 of Set 6 | polunochnoye
# Processing Record 20 of Set 6 | daru
# Processing Record 21 of Set 6 | howard springs
# Processing Record 22 of Set 6 | bethel
# Processing Record 23 of Set 6 | nanortalik
# Processing Record 24 of Set 6 | georgetown
# Processing Record 25 of Set 6 | pokrovsk
# Processing Record 26 of Set 6 | segamat
# Processing Record 27 of Set 6 | mahebourg
# Processing Record 28 of Set 6 | cocobeach
# Processing Record 29 of Set 6 | ahipara
# Processing Record 30 of Set 6 | omura
# Processing Record 31 of Set 6 | adrar
# Processing Record 32 of Set 6 | doha
# Processing Record 33 of Set 6 | necochea
# Processing Record 34 of Set 6 | virginia beach
# Processing Record 35 of Set 6 | itirapina
# Processing Record 36 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 6 | port blair
# Processing Record 38 of Set 6 | shimoda
# Processing Record 39 of Set 6 | ipeti
# City not found. Skipping...
# Processing Record 40 of Set 6 | constitucion
# Processing Record 41 of Set 6 | goderich
# Processing Record 42 of Set 6 | hami
# Processing Record 43 of Set 6 | coihaique
# Processing Record 44 of Set 6 | cheyenne
# Processing Record 45 of Set 6 | venta
# Processing Record 46 of Set 6 | kaitangata
# Processing Record 47 of Set 6 | homer
# Processing Record 48 of Set 6 | birao
# Processing Record 49 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 50 of Set 6 | sinop
# Processing Record 1 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 2 of Set 7 | walkerburn
# Processing Record 3 of Set 7 | nhulunbuy
# Processing Record 4 of Set 7 | erenhot
# Processing Record 5 of Set 7 | baykit
# Processing Record 6 of Set 7 | fredericton
# Processing Record 7 of Set 7 | vao
# Processing Record 8 of Set 7 | fort nelson
# Processing Record 9 of Set 7 | san alberto
# Processing Record 10 of Set 7 | kloulklubed
# Processing Record 11 of Set 7 | cayenne
# Processing Record 12 of Set 7 | khash
# Processing Record 13 of Set 7 | nizhniy kuranakh
# Processing Record 14 of Set 7 | semnan
# Processing Record 15 of Set 7 | saint george
# Processing Record 16 of Set 7 | grafton
# Processing Record 17 of Set 7 | buxar
# Processing Record 18 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 7 | vestmannaeyjar
# Processing Record 20 of Set 7 | poum
# Processing Record 21 of Set 7 | thibodaux
# Processing Record 22 of Set 7 | belmonte
# Processing Record 23 of Set 7 | padra
# Processing Record 24 of Set 7 | dunajska streda
# Processing Record 25 of Set 7 | fortuna
# Processing Record 26 of Set 7 | filadelfia
# Processing Record 27 of Set 7 | muroto
# Processing Record 28 of Set 7 | khrustalnyy
# City not found. Skipping...
# Processing Record 29 of Set 7 | saint-philippe
# Processing Record 30 of Set 7 | madang
# Processing Record 31 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 32 of Set 7 | muisne
# Processing Record 33 of Set 7 | san rafael
# Processing Record 34 of Set 7 | gizo
# Processing Record 35 of Set 7 | puro
# Processing Record 36 of Set 7 | jiaxing
# Processing Record 37 of Set 7 | price
# Processing Record 38 of Set 7 | sukhobuzimskoye
# Processing Record 39 of Set 7 | mendeleyevo
# Processing Record 40 of Set 7 | huilong
# Processing Record 41 of Set 7 | burica
# City not found. Skipping...
# Processing Record 42 of Set 7 | vrangel
# Processing Record 43 of Set 7 | namibe
# Processing Record 44 of Set 7 | plettenberg bay
# Processing Record 45 of Set 7 | meulaboh
# Processing Record 46 of Set 7 | andenes
# Processing Record 47 of Set 7 | umm lajj
# Processing Record 48 of Set 7 | bathsheba
# Processing Record 49 of Set 7 | jumla
# Processing Record 50 of Set 7 | bauchi
# Processing Record 1 of Set 8 | kirovskiy
# Processing Record 2 of Set 8 | paamiut
# Processing Record 3 of Set 8 | falun
# Processing Record 4 of Set 8 | antas
# Processing Record 5 of Set 8 | requena
# Processing Record 6 of Set 8 | tilichiki
# Processing Record 7 of Set 8 | rawson
# Processing Record 8 of Set 8 | lekoni
# Processing Record 9 of Set 8 | qandala
# Processing Record 10 of Set 8 | ati
# Processing Record 11 of Set 8 | baracoa
# Processing Record 12 of Set 8 | dunedin
# Processing Record 13 of Set 8 | nabire
# Processing Record 14 of Set 8 | bodden town
# Processing Record 15 of Set 8 | xichang
# Processing Record 16 of Set 8 | inongo
# Processing Record 17 of Set 8 | abbeville
# Processing Record 18 of Set 8 | benghazi
# Processing Record 19 of Set 8 | aalestrup
# City not found. Skipping...
# Processing Record 20 of Set 8 | dongli
# Processing Record 21 of Set 8 | cabatuan
# Processing Record 22 of Set 8 | san vicente
# Processing Record 23 of Set 8 | lensk
# Processing Record 24 of Set 8 | abu kamal
# Processing Record 25 of Set 8 | saldanha
# Processing Record 26 of Set 8 | los llanos de aridane
# Processing Record 27 of Set 8 | yauya
# Processing Record 28 of Set 8 | dhidhdhoo
# Processing Record 29 of Set 8 | atasu
# Processing Record 30 of Set 8 | yuksekova
# Processing Record 31 of Set 8 | choctaw
# Processing Record 32 of Set 8 | bairiki
# Processing Record 33 of Set 8 | tomatlan
# Processing Record 34 of Set 8 | malibu
# Processing Record 35 of Set 8 | roma
# Processing Record 36 of Set 8 | cururupu
# Processing Record 37 of Set 8 | kazachinskoye
# Processing Record 38 of Set 8 | mecca
# Processing Record 39 of Set 8 | otradnoye
# Processing Record 40 of Set 8 | nara
# Processing Record 41 of Set 8 | torbay
# Processing Record 42 of Set 8 | concepcion del uruguay
# Processing Record 43 of Set 8 | ndiekro
# City not found. Skipping...
# Processing Record 44 of Set 8 | guaymas
# Processing Record 45 of Set 8 | safaga
# Processing Record 46 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 47 of Set 8 | nargana
# Processing Record 48 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 8 | bilma
# Processing Record 50 of Set 8 | osakarovka
# Processing Record 1 of Set 9 | buraydah
# Processing Record 2 of Set 9 | iqaluit
# Processing Record 3 of Set 9 | belle fourche
# Processing Record 4 of Set 9 | kodinsk
# Processing Record 5 of Set 9 | qaqortoq
# Processing Record 6 of Set 9 | nemuro
# Processing Record 7 of Set 9 | isangel
# Processing Record 8 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 9 | gisborne
# Processing Record 10 of Set 9 | quelimane
# Processing Record 11 of Set 9 | saint-francois
# Processing Record 12 of Set 9 | nalut
# Processing Record 13 of Set 9 | shiyan
# Processing Record 14 of Set 9 | tayu
# Processing Record 15 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 9 | todos santos
# Processing Record 17 of Set 9 | namatanai
# Processing Record 18 of Set 9 | itoman
# Processing Record 19 of Set 9 | olinda
# Processing Record 20 of Set 9 | oriximina
# Processing Record 21 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 9 | port-gentil
# Processing Record 23 of Set 9 | naron
# Processing Record 24 of Set 9 | severo-kurilsk
# Processing Record 25 of Set 9 | gidole
# Processing Record 26 of Set 9 | yambio
# Processing Record 27 of Set 9 | hangal
# Processing Record 28 of Set 9 | barabai
# Processing Record 29 of Set 9 | mezen
# Processing Record 30 of Set 9 | makat
# Processing Record 31 of Set 9 | clyde river
# Processing Record 32 of Set 9 | joensuu
# Processing Record 33 of Set 9 | sorland
# Processing Record 34 of Set 9 | ancud
# Processing Record 35 of Set 9 | cherskiy
# Processing Record 36 of Set 9 | zhezkazgan
# Processing Record 37 of Set 9 | dawei
# Processing Record 38 of Set 9 | yelniki
# Processing Record 39 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 9 | saint-augustin
# Processing Record 41 of Set 9 | oum hadjer
# Processing Record 42 of Set 9 | bosaso
# Processing Record 43 of Set 9 | troitsko-pechorsk
# Processing Record 44 of Set 9 | paracuru
# Processing Record 45 of Set 9 | dukat
# Processing Record 46 of Set 9 | touros
# Processing Record 47 of Set 9 | general roca
# Processing Record 48 of Set 9 | trofors
# Processing Record 49 of Set 9 | the valley
# Processing Record 50 of Set 9 | yichang
# Processing Record 1 of Set 10 | bengkulu
# Processing Record 2 of Set 10 | slave lake
# Processing Record 3 of Set 10 | carbonia
# Processing Record 4 of Set 10 | labuhan
# Processing Record 5 of Set 10 | kristiinankaupunki
# Processing Record 6 of Set 10 | batagay-alyta
# Processing Record 7 of Set 10 | santa catalina
# Processing Record 8 of Set 10 | northam
# Processing Record 9 of Set 10 | mulanje
# Processing Record 10 of Set 10 | nouadhibou
# Processing Record 11 of Set 10 | beringovskiy
# Processing Record 12 of Set 10 | cabra
# Processing Record 13 of Set 10 | kungurtug
# Processing Record 14 of Set 10 | santa
# Processing Record 15 of Set 10 | muros
# Processing Record 16 of Set 10 | sibu
# Processing Record 17 of Set 10 | yining
# Processing Record 18 of Set 10 | almenara
# Processing Record 19 of Set 10 | iralaya
# Processing Record 20 of Set 10 | manuk mangkaw
# Processing Record 21 of Set 10 | ewo
# Processing Record 22 of Set 10 | eureka
# Processing Record 23 of Set 10 | deputatskiy
# Processing Record 24 of Set 10 | umea
# Processing Record 25 of Set 10 | alofi
# Processing Record 26 of Set 10 | san andres
# Processing Record 27 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 10 | itarema
# Processing Record 29 of Set 10 | saint-pierre
# Processing Record 30 of Set 10 | kristianstad
# Processing Record 31 of Set 10 | ukhta
# Processing Record 32 of Set 10 | lagoa
# Processing Record 33 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 10 | king city
# Processing Record 35 of Set 10 | sitka
# Processing Record 36 of Set 10 | praya
# Processing Record 37 of Set 10 | flinders
# Processing Record 38 of Set 10 | kachug
# Processing Record 39 of Set 10 | belaya gora
# Processing Record 40 of Set 10 | atocha
# Processing Record 41 of Set 10 | anadyr
# Processing Record 42 of Set 10 | torrevieja
# Processing Record 43 of Set 10 | bama
# Processing Record 44 of Set 10 | roebourne
# Processing Record 45 of Set 10 | jeremie
# Processing Record 46 of Set 10 | nishihara
# Processing Record 47 of Set 10 | zhangye
# Processing Record 48 of Set 10 | cabedelo
# Processing Record 49 of Set 10 | sweetwater
# Processing Record 50 of Set 10 | suffolk
# Processing Record 1 of Set 11 | atar
# Processing Record 2 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 11 | xinxiang
# Processing Record 4 of Set 11 | whitehorse
# Processing Record 5 of Set 11 | yartsevo
# Processing Record 6 of Set 11 | aitape
# Processing Record 7 of Set 11 | half moon bay
# Processing Record 8 of Set 11 | san angelo
# Processing Record 9 of Set 11 | san antonio
# Processing Record 10 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 11 | lufilufi
# Processing Record 12 of Set 11 | saint augustine
# Processing Record 13 of Set 11 | calama
# Processing Record 14 of Set 11 | nizhniy odes
# Processing Record 15 of Set 11 | saint anthony
# Processing Record 16 of Set 11 | east wenatchee bench
# Processing Record 17 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 11 | henties bay
# Processing Record 19 of Set 11 | launceston
# Processing Record 20 of Set 11 | oktyabrskiy
# Processing Record 21 of Set 11 | evensk
# Processing Record 22 of Set 11 | gasa
# Processing Record 23 of Set 11 | kysyl-syr
# Processing Record 24 of Set 11 | sakaiminato
# Processing Record 25 of Set 11 | coquimbo
# Processing Record 26 of Set 11 | sao joao da barra
# Processing Record 27 of Set 11 | margate
# Processing Record 28 of Set 11 | moron
# Processing Record 29 of Set 11 | houma
# Processing Record 30 of Set 11 | koutsouras
# Processing Record 31 of Set 11 | udachnyy
# Processing Record 32 of Set 11 | broome
# Processing Record 33 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 34 of Set 11 | phan thiet
# Processing Record 35 of Set 11 | ishigaki
# Processing Record 36 of Set 11 | wairoa
# Processing Record 37 of Set 11 | kamenka
# Processing Record 38 of Set 11 | nuevo progreso
# Processing Record 39 of Set 11 | tromso
# Processing Record 40 of Set 11 | abnub
# Processing Record 41 of Set 11 | torbat-e jam
# Processing Record 42 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 11 | yazd
# Processing Record 44 of Set 11 | maniitsoq
# Processing Record 45 of Set 11 | huercal-overa
# Processing Record 46 of Set 11 | kundiawa
# Processing Record 47 of Set 11 | kahului
# Processing Record 48 of Set 11 | forssa
# Processing Record 49 of Set 11 | djibo
# Processing Record 50 of Set 11 | sungaipenuh
# Processing Record 1 of Set 12 | kirakira
# Processing Record 2 of Set 12 | kampot
# Processing Record 3 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 4 of Set 12 | rocha
# Processing Record 5 of Set 12 | agnibilekrou
# Processing Record 6 of Set 12 | mehran
# Processing Record 7 of Set 12 | bara
# Processing Record 8 of Set 12 | pangnirtung
# Processing Record 9 of Set 12 | nyurba
# Processing Record 10 of Set 12 | grand gaube
# Processing Record 11 of Set 12 | aswan
# Processing Record 12 of Set 12 | terme
# Processing Record 13 of Set 12 | staunton
# Processing Record 14 of Set 12 | te anau
# Processing Record 15 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 16 of Set 12 | ulladulla
# Processing Record 17 of Set 12 | edd
# Processing Record 18 of Set 12 | noumea
# Processing Record 19 of Set 12 | remedios
# Processing Record 20 of Set 12 | uttiramerur
# Processing Record 21 of Set 12 | tabou
# Processing Record 22 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 23 of Set 12 | vallenar
# Processing Record 24 of Set 12 | pemangkat
# Processing Record 25 of Set 12 | rincon
# Processing Record 26 of Set 12 | sibolga
# Processing Record 27 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 29 of Set 12 | kaina
# Processing Record 30 of Set 12 | aipe
# Processing Record 31 of Set 12 | frontera
# Processing Record 32 of Set 12 | uberlandia
# Processing Record 33 of Set 12 | beloha
# Processing Record 34 of Set 12 | traverse city
# Processing Record 35 of Set 12 | coahuayana
# Processing Record 36 of Set 12 | bossembele
# City not found. Skipping...
# Processing Record 37 of Set 12 | ambilobe
# Processing Record 38 of Set 12 | marzuq
# Processing Record 39 of Set 12 | rancho palos verdes
# Processing Record 40 of Set 12 | nacala
# Processing Record 41 of Set 12 | talara
# Processing Record 42 of Set 12 | puerto leguizamo
# Processing Record 43 of Set 12 | parsabad
# Processing Record 44 of Set 12 | barra patuca
# Processing Record 45 of Set 12 | birin
# Processing Record 46 of Set 12 | puerto madero
# Processing Record 47 of Set 12 | siocon
# Processing Record 48 of Set 12 | marsa matruh
# Processing Record 49 of Set 12 | dolneni
# Processing Record 50 of Set 12 | waitara
# Processing Record 1 of Set 13 | viedma
# Processing Record 2 of Set 13 | chernogorsk
# Processing Record 3 of Set 13 | graciano sanchez
# Processing Record 4 of Set 13 | osa
# Processing Record 5 of Set 13 | mbaiki
# Processing Record 6 of Set 13 | fort myers beach
# Processing Record 7 of Set 13 | inta
# Processing Record 8 of Set 13 | la rioja
# Processing Record 9 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 13 | akdepe
# Processing Record 11 of Set 13 | arinos
# Processing Record 12 of Set 13 | hebertville
# City not found. Skipping...
# Processing Record 13 of Set 13 | neiafu
# Processing Record 14 of Set 13 | ndele
# Processing Record 15 of Set 13 | santa vitoria do palmar
# Processing Record 16 of Set 13 | khandyga
# Processing Record 17 of Set 13 | manzhouli
# Processing Record 18 of Set 13 | taoudenni
# Processing Record 19 of Set 13 | ballina
# Processing Record 20 of Set 13 | camacupa
# Processing Record 21 of Set 13 | salmon arm
# Processing Record 22 of Set 13 | songjianghe
# Processing Record 23 of Set 13 | waconia
# Processing Record 24 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 25 of Set 13 | urucui
# Processing Record 26 of Set 13 | san juan
# Processing Record 27 of Set 13 | puruandiro
# Processing Record 28 of Set 13 | mayor pablo lagerenza
# Processing Record 29 of Set 13 | montanha
# Processing Record 30 of Set 13 | axim
# Processing Record 31 of Set 13 | comodoro rivadavia
# Processing Record 32 of Set 13 | oussouye
# Processing Record 33 of Set 13 | besancon
# Processing Record 34 of Set 13 | buala
# Processing Record 35 of Set 13 | leh
# Processing Record 36 of Set 13 | samarinda
# Processing Record 37 of Set 13 | abha
# Processing Record 38 of Set 13 | aripuana
# Processing Record 39 of Set 13 | alindao
# Processing Record 40 of Set 13 | bosilegrad
# Processing Record 41 of Set 13 | awbari
# Processing Record 42 of Set 13 | saint-leu
# Processing Record 43 of Set 13 | bom jardim
# Processing Record 44 of Set 13 | biga
# Processing Record 45 of Set 13 | roald
# Processing Record 46 of Set 13 | akyab
# Processing Record 47 of Set 13 | praia da vitoria
# Processing Record 48 of Set 13 | port moresby
# Processing Record 49 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 13 | raton
# Processing Record 1 of Set 14 | port keats
# Processing Record 2 of Set 14 | araouane
# Processing Record 3 of Set 14 | asfi
# Processing Record 4 of Set 14 | xifeng
# Processing Record 5 of Set 14 | kuloy
# Processing Record 6 of Set 14 | zhifang
# Processing Record 7 of Set 14 | saint-joseph
# Processing Record 8 of Set 14 | acapulco
# Processing Record 9 of Set 14 | la reforma
# Processing Record 10 of Set 14 | siavonga
# Processing Record 11 of Set 14 | dhandhuka
# Processing Record 12 of Set 14 | tonota
# Processing Record 13 of Set 14 | bawku
# Processing Record 14 of Set 14 | seoul
# Processing Record 15 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 14 | leshan
# Processing Record 17 of Set 14 | dawlatabad
# Processing Record 18 of Set 14 | bac lieu
# Processing Record 19 of Set 14 | la palma
# Processing Record 20 of Set 14 | freeport
# Processing Record 21 of Set 14 | boende
# Processing Record 22 of Set 14 | hambantota
# Processing Record 23 of Set 14 | limot
# Processing Record 24 of Set 14 | baoma
# Processing Record 25 of Set 14 | zaysan
# Processing Record 26 of Set 14 | tatawin
# Processing Record 27 of Set 14 | dromolaxia
# Processing Record 28 of Set 14 | coffs harbour
# Processing Record 29 of Set 14 | ketchikan
# Processing Record 30 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 14 | muravlenko
# Processing Record 32 of Set 14 | abdanan
# Processing Record 33 of Set 14 | vikhorevka
# Processing Record 34 of Set 14 | gat
# Processing Record 35 of Set 14 | kokopo
# Processing Record 36 of Set 14 | bako
# Processing Record 37 of Set 14 | gollere
# City not found. Skipping...
# Processing Record 38 of Set 14 | labrea
# Processing Record 39 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 40 of Set 14 | westport
# Processing Record 41 of Set 14 | mochalishche
# Processing Record 42 of Set 14 | erdenet
# Processing Record 43 of Set 14 | yemelyanovo
# Processing Record 44 of Set 14 | floro
# Processing Record 45 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 46 of Set 14 | gulu
# Processing Record 47 of Set 14 | marang
# Processing Record 48 of Set 14 | honiara
# Processing Record 49 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 50 of Set 14 | algiers
# Processing Record 1 of Set 15 | bowling green
# Processing Record 2 of Set 15 | conde
# Processing Record 3 of Set 15 | caluquembe
# Processing Record 4 of Set 15 | brae
# Processing Record 5 of Set 15 | burnie
# Processing Record 6 of Set 15 | krasnoselkup
# Processing Record 7 of Set 15 | kihei
# Processing Record 8 of Set 15 | omboue
# Processing Record 9 of Set 15 | riyadh
# Processing Record 10 of Set 15 | yarim
# Processing Record 11 of Set 15 | monrovia
# Processing Record 12 of Set 15 | bereda
# Processing Record 13 of Set 15 | susuman
# Processing Record 14 of Set 15 | cocachacra
# Processing Record 15 of Set 15 | savannah bight
# Processing Record 16 of Set 15 | sisimiut
# Processing Record 17 of Set 15 | marsh harbour
# Processing Record 18 of Set 15 | madimba
# Processing Record 19 of Set 15 | dauphin
# Processing Record 20 of Set 15 | pierre
# Processing Record 21 of Set 15 | aksarka
# Processing Record 22 of Set 15 | santiago del estero
# Processing Record 23 of Set 15 | kargopol
# Processing Record 24 of Set 15 | kachiry
# Processing Record 25 of Set 15 | sao caetano de odivelas
# Processing Record 26 of Set 15 | porto santo
# Processing Record 27 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 15 | menongue
# Processing Record 29 of Set 15 | pontianak
# Processing Record 30 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 31 of Set 15 | wana
# Processing Record 32 of Set 15 | caranavi
# Processing Record 33 of Set 15 | mandiana
# Processing Record 34 of Set 15 | wanaka
# Processing Record 35 of Set 15 | mumford
# Processing Record 36 of Set 15 | ibra
# Processing Record 37 of Set 15 | lazaro cardenas
# Processing Record 38 of Set 15 | talaya
# Processing Record 39 of Set 15 | vada
# Processing Record 40 of Set 15 | novopskov
# Processing Record 41 of Set 15 | nicolas bravo
# Processing Record 42 of Set 15 | anloga
# Processing Record 43 of Set 15 | usinsk
# Processing Record 44 of Set 15 | santa isabel
# Processing Record 45 of Set 15 | jalcocotan
# Processing Record 46 of Set 15 | tarko-sale
# Processing Record 47 of Set 15 | tikaitnagar
# Processing Record 48 of Set 15 | chernyshevskiy
# Processing Record 49 of Set 15 | linjiang
# Processing Record 50 of Set 15 | orotukan
# Processing Record 1 of Set 16 | zyryanovsk
# Processing Record 2 of Set 16 | sabang
# Processing Record 3 of Set 16 | ouango
# Processing Record 4 of Set 16 | shingu
# Processing Record 5 of Set 16 | makakilo city
# Processing Record 6 of Set 16 | becerril
# Processing Record 7 of Set 16 | masindi
# Processing Record 8 of Set 16 | hasanabad
# Processing Record 9 of Set 16 | bom jesus
# Processing Record 10 of Set 16 | maragogi
# Processing Record 11 of Set 16 | chara
# Processing Record 12 of Set 16 | yelizovo
# Processing Record 13 of Set 16 | port-cartier
# Processing Record 14 of Set 16 | yar-sale
# Processing Record 15 of Set 16 | strangnas
# Processing Record 16 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 16 | touba
# Processing Record 18 of Set 16 | gondanglegi
# Processing Record 19 of Set 16 | rawah
# Processing Record 20 of Set 16 | sabla
# Processing Record 21 of Set 16 | ixtapa
# Processing Record 22 of Set 16 | merrill
# Processing Record 23 of Set 16 | sarankhola
# Processing Record 24 of Set 16 | prieska
# Processing Record 25 of Set 16 | maple creek
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Najran  17.4924   44.1277     61.45        22          37        2.59
# 1     Chapais  49.7834  -74.8492     49.78        89         100       12.80
# 2      Atuona  -9.8000 -139.0333     77.25        78          14       20.67
# 3   Jamestown  42.0970  -79.2353     63.99        56         100       19.57
# 4     Rikitea -23.1203 -134.9692     69.21        62           0       15.30
# 5       Basco  20.4487  121.9702     81.09        83          64       27.63
# 6       Vaini -21.2000 -175.2000     80.76        74          20       10.36
# 7        Hilo  19.7297 -155.0900     84.27        83           0        6.91
# 8  Butaritari   3.0707  172.7902     82.27        75           5       20.27
# 9    Thompson  55.7435  -97.8558     33.96        93         100       19.57
#
#   Country Current Description
# 0      SA    scattered clouds
# 1      CA          light rain
# 2      PF          few clouds
# 3      US     overcast clouds
# 4      PF           clear sky
# 5      PH       broken clouds
# 6      TO          few clouds
# 7      US           clear sky
# 8      KI           clear sky
# 9      CA     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

reorder_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reorder_columns]

# Display sample data
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Najran      SA  17.4924   44.1277     61.45        22          37
# 1     Chapais      CA  49.7834  -74.8492     49.78        89         100
# 2      Atuona      PF  -9.8000 -139.0333     77.25        78          14
# 3   Jamestown      US  42.0970  -79.2353     63.99        56         100
# 4     Rikitea      PF -23.1203 -134.9692     69.21        62           0
# 5       Basco      PH  20.4487  121.9702     81.09        83          64
# 6       Vaini      TO -21.2000 -175.2000     80.76        74          20
# 7        Hilo      US  19.7297 -155.0900     84.27        83           0
# 8  Butaritari      KI   3.0707  172.7902     82.27        75           5
# 9    Thompson      CA  55.7435  -97.8558     33.96        93         100
#
#    Wind Speed Current Description
# 0        2.59    scattered clouds
# 1       12.80          light rain
# 2       20.67          few clouds
# 3       19.57     overcast clouds
# 4       15.30           clear sky
# 5       27.63       broken clouds
# 6       10.36          few clouds
# 7        6.91           clear sky
# 8       20.27           clear sky
# 9       19.57     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'weather_database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
